# %%
import Oracle
# Out:
# [1942]
# Done with MU
# Waiting...
# [1942, 1941]
# Done with MSFT
# Waiting...
# [1942, 1941, 1936]
# Done with NEM
# Waiting...
# [1942, 1941, 1936, 1938]
# Done with FB
# Waiting...
# Finished with stock list.
# 1
# Done with MU
# Waiting...
# [1942]
# Done with MSFT
# Waiting...
# [1942, 1937]
# Done with NEM
# Waiting...
# [1942, 1937, 1936]
# Done with FB
# Waiting...
# [1942, 1937, 1936, 1938]
# 2
# Done with MU
# Waiting...
# [1942]
# Done with MSFT
# Waiting...
# [1942, 1941]
# Done with NEM
# Waiting...
# [1942, 1941, 1936]
# Done with FB
# Waiting...
# [1942, 1941, 1936, 1938]
# 3
# Done with MU
# Waiting...
# [1938]
# Done with MSFT
# Waiting...
# [1938, 1941]
# Done with NEM
# Waiting...
# [1938, 1941, 1936]
# Done with FB
# Waiting...
# [1938, 1941, 1936, 1938]
# 4
# Done with MU
# Waiting...
# [1942]
# Done with MSFT
# Waiting...
# [1942, 1941]
# Done with NEM
# Waiting...
# [1942, 1941, 1936]
# Done with FB
# Waiting...
# [1942, 1941, 1936, 1938]
# 5
# Done with MU
# ...

# %%
import Oracle
# Out:
# [1942]
# Done with MU
# Waiting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-40f22b29ef5d> in <module>
# ----> 1 import Oracle
#
# ~\Trading Program\TradingProgram\Oracle.py in <module>
#      23     print('Done with ' + str(i))
#      24     print(r'Waiting...')
# ---> 25     time.sleep(15)
#      26 print('Finished with stock list.')
#      27
#
# KeyboardInterrupt:
