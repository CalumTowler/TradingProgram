# %%
import alpha_vantage
import pandas
import time
from alpha_vantage.timeseries import TimeSeries

# %%
MyKey ='28M2VQTADUQ0HSCP'
ts = TimeSeries(MyKey)

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1939
# {'2019-12-05 11:32:00', '2019-12-04 11:31:00', '2019-12-05 11:31:00', '2019-12-04 11:37:00', '2019-12-06 09:33:00', '2019-12-06 09:32:00', '2019-12-04 11:32:00', '2019-12-06 12:06:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1941
# 1939
# {'2019-12-05 11:01:00', '2019-12-05 11:31:00', '2019-12-04 11:57:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1930
# {'2019-12-03 11:33:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1930
# {'2019-12-03 11:33:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1939
# {'2019-12-05 11:32:00', '2019-12-04 11:31:00', '2019-12-05 11:31:00', '2019-12-04 11:37:00', '2019-12-06 09:33:00', '2019-12-06 09:32:00', '2019-12-04 11:32:00', '2019-12-06 12:06:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1939
# {'2019-12-05 11:32:00', '2019-12-04 11:31:00', '2019-12-05 11:31:00', '2019-12-04 11:37:00', '2019-12-06 09:33:00', '2019-12-06 09:32:00', '2019-12-04 11:32:00', '2019-12-06 12:06:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1931
# 1939
# {'2019-12-05 11:32:00', '2019-12-04 11:31:00', '2019-12-05 11:31:00', '2019-12-04 11:37:00', '2019-12-06 09:33:00', '2019-12-06 09:32:00', '2019-12-04 11:32:00', '2019-12-06 12:06:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1720
# 1716
# {'2019-12-05 11:01:00', '2019-12-11 12:14:00', '2019-12-11 12:16:00', '2019-12-05 11:31:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1720
# 1718
# {'2019-12-05 11:01:00', '2019-12-11 12:14:00', '2019-12-05 11:31:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(5)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
# Out:
# 1720
# 1718
# {'2019-12-05 11:01:00', '2019-12-11 12:14:00', '2019-12-05 11:31:00'}

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
time.sleep(20)
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
time.sleep(20)
while data or data2 < 1950:
    data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
    print(len(data))
    time.sleep(20)
    data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
    print(len(data2))
    print(set(data.keys()).difference(data2.keys()))
# Out:
# 1944
# 1942
# {'2019-12-05 11:01:00', '2019-12-06 11:08:00', '2019-12-11 11:02:00', '2019-12-09 10:52:00', '2019-12-10 14:39:00', '2019-12-11 11:01:00', '2019-12-10 14:38:00'}
# 1942
# 1942
# set()
# 1942
# 1942
# set()
# 1944
# 1942
# {'2019-12-05 11:01:00', '2019-12-06 11:08:00', '2019-12-11 11:02:00', '2019-12-09 10:52:00', '2019-12-10 14:39:00', '2019-12-11 11:01:00', '2019-12-10 14:38:00'}
# 1944
# 1942
# {'2019-12-05 11:01:00', '2019-12-06 11:08:00', '2019-12-11 11:02:00', '2019-12-09 10:52:00', '2019-12-10 14:39:00', '2019-12-11 11:01:00', '2019-12-10 14:38:00'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-0502136dc1e6> in <module>
#       7 time.sleep(20)
#       8 while data or data2 < 1950:
# ----> 9     data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
#      10     print(len(data))
#      11     time.sleep(20)
#
# ~\Anaconda3\envs\TradingProgram\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     176             if 'json' in self.output_format.lower() or 'pandas' \
#     177                     in self.output_format.lower():
# --> 178                 data = call_response[data_key]
#     179                 if meta_data_key is not None:
#     180                     meta_data = call_response[meta_data_key]
#
# KeyError: 'Time Series (1min)'

# %%
print(data)
# Out:
# {'2019-12-11 14:38:00': {'1. open': '151.3900', '2. high': '151.4800', '3. low': '151.3900', '4. close': '151.4800', '5. volume': '25401'}, '2019-12-11 14:37:00': {'1. open': '151.3775', '2. high': '151.3900', '3. low': '151.3600', '4. close': '151.3900', '5. volume': '13219'}, '2019-12-11 14:36:00': {'1. open': '151.4000', '2. high': '151.4000', '3. low': '151.3600', '4. close': '151.3900', '5. volume': '14632'}, '2019-12-11 14:35:00': {'1. open': '151.3500', '2. high': '151.4066', '3. low': '151.3500', '4. close': '151.4000', '5. volume': '15471'}, '2019-12-11 14:34:00': {'1. open': '151.4000', '2. high': '151.4099', '3. low': '151.3500', '4. close': '151.3541', '5. volume': '35787'}, '2019-12-11 14:33:00': {'1. open': '151.4100', '2. high': '151.4150', '3. low': '151.3900', '4. close': '151.4000', '5. volume': '18803'}, '2019-12-11 14:32:00': {'1. open': '151.4100', '2. high': '151.4200', '3. low': '151.4041', '4. close': '151.4134', '5. volume': '15693'}, '2019-12-11 14:31:00': {'1. open': '151.3900', '2. high': '151.3900', '3. low': '151.3400', '4. close': '151.3900', '5. volume': '15248'}, '2019-12-11 14:30:00': {'1. open': '151.3656', '2. high': '151.4000', '3. low': '151.3600', '4. close': '151.3900', '5. volume': '13446'}, '2019-12-11 14:29:00': {'1. open': '151.3885', '2. high': '151.3983', '3. low': '151.3700', '4. close': '151.3750', '5. volume': '25451'}, '2019-12-11 14:28:00': {'1. open': '151.3800', '2. high': '151.4129', '3. low': '151.3800', '4. close': '151.3890', '5. volume': '11656'}, '2019-12-11 14:27:00': {'1. open': '151.4330', '2. high': '151.4350', '3. low': '151.3850', '4. close': '151.3850', '5. volume': '29590'}, '2019-12-11 14:26:00': {'1. open': '151.5000', '2. high': '151.5293', '3. low': '151.4300', '4. close': '151.4350', '5. volume': '26802'}, '2019-12-11 14:25:00': {'1. open': '151.5500', '2. high': '151.5700', '3. low': '151.4969', '4. close': '151.5000', '5. volume': '29341'}, '2019-12-11 14:24:00': {'1. open': '151.4200', '2. high': '151.5500', '3. low': '151.4200', '4. close': '151.5500', '5. volume': '0'}, '2019-12-11 14:23:00': {'1. open': '151.4300', '2. high': '151.4500', '3. low': '151.4100', '4. close': '151.4100', '5. volume': '32559'}, '2019-12-11 14:22:00': {'1. open': '151.4100', '2. high': '151.4400', '3. low': '151.3920', '4. close': '151.4300', '5. volume': '28067'}, '2019-12-11 14:21:00': {'1. open': '151.4100', '2. high': '151.4400', '3. low': '151.4000', '4. close': '151.4000', '5. volume': '14255'}, '2019-12-11 14:20:00': {'1. open': '151.4203', '2. high': '151.4300', '3. low': '151.4066', '4. close': '151.4200', '5. volume': '24204'}, '2019-12-11 14:19:00': {'1. open': '151.3850', '2. high': '151.4700', '3. low': '151.3850', '4. close': '151.4200', '5. volume': '57730'}, '2019-12-11 14:18:00': {'1. open': '151.3700', '2. high': '151.4200', '3. low': '151.3650', '4. close': '151.3850', '5. volume': '85661'}, '2019-12-11 14:17:00': {'1. open': '151.3350', '2. high': '151.3700', '3. low': '151.3200', '4. close': '151.3650', '5. volume': '14824'}, '2019-12-11 14:16:00': {'1. open': '151.2600', '2. high': '151.3300', '3. low': '151.2599', '4. close': '151.3300', '5. volume': '18357'}, '2019-12-11 14:15:00': {'1. open': '151.2728', '2. high': '151.3000', '3. low': '151.2500', '4. close': '151.2550', '5. volume': '28144'}, '2019-12-11 14:14:00': {'1. open': '151.2300', '2. high': '151.2900', '3. low': '151.2300', '4. close': '151.2825', '5. volume': '19596'}, '2019-12-11 14:13:00': {'1. open': '151.2600', '2. high': '151.2950', '3. low': '151.2350', '4. close': '151.2400', '5. volume': '12853'}, '2019-12-11 14:12:00': {'1. open': '151.2350', '2. high': '151.2800', '3. low': '151.2350', '4. close': '151.2625', '5. volume': '15411'}, '2019-12-11 14:11:00': {'1. open': '151.2850', '2. high': '151.2899', '3. low': '151.2050', '4. close': '151.2400', '5. volume': '23137'}, '2019-12-11 14:10:00': {'1. open': '151.2867', '2. high': '151.2900', '3. low': '151.2700', '4. close': '151.29 ...

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
while len(data) != len(data2):
    time.sleep(20)
    data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
    print(len(data))
    time.sleep(20)
    data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
    print(len(data2))
    print(set(data.keys()).difference(data2.keys()))
# Out:
# 1948
# 1943
# {'2019-12-12 11:00:00', '2019-12-11 11:02:00', '2019-12-09 10:52:00', '2019-12-10 14:39:00', '2019-12-13 11:04:00', '2019-12-11 11:01:00', '2019-12-10 14:38:00'}
# 1948
# 1948
# set()

# %%
data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
print(len(data))
data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
print(len(data2))
print(set(data.keys()).difference(data2.keys()))
while len(data) != len(data2):
    time.sleep(20)
    data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
    print(len(data))
    time.sleep(20)
    data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
    print(len(data2))
    print(set(data.keys()).difference(data2.keys()))
# Out:
# 1941
# 1942
# set()
# 1941
# 1942
# set()
# 1937
# 1942
# {'2019-12-12 10:57:00', '2019-12-16 11:32:00', '2019-12-16 12:01:00', '2019-12-17 11:00:00', '2019-12-18 12:01:00', '2019-12-18 12:03:00'}
# 1941
# 1942
# set()
# 1941
# 1942
# set()
# 1937
# 1942
# {'2019-12-12 10:57:00', '2019-12-16 11:32:00', '2019-12-16 12:01:00', '2019-12-17 11:00:00', '2019-12-18 12:01:00', '2019-12-18 12:03:00'}
# 1941
# 1942
# set()
# 1937
# 1942
# {'2019-12-12 10:57:00', '2019-12-16 11:32:00', '2019-12-16 12:01:00', '2019-12-17 11:00:00', '2019-12-18 12:01:00', '2019-12-18 12:03:00'}
# 1937
# 1942
# {'2019-12-12 10:57:00', '2019-12-16 11:32:00', '2019-12-16 12:01:00', '2019-12-17 11:00:00', '2019-12-18 12:01:00', '2019-12-18 12:03:00'}
# 1941
# 1938
# {'2019-12-17 12:01:00', '2019-12-12 11:00:00', '2019-12-16 11:02:00', '2019-12-18 11:01:00', '2019-12-18 11:31:00', '2019-12-16 09:32:00', '2019-12-16 09:33:00', '2019-12-17 11:29:00', '2019-12-13 11:04:00', '2019-12-16 12:00:00'}
# 1937
# 1938
# set()
# 1937
# 1942
# {'2019-12-12 10:57:00', '2019-12-16 11:32:00', '2019-12-16 12:01:00', '2019-12-17 11:00:00', '2019-12-18 12:01:00', '2019-12-18 12:03:00'}
# 1937
# 1938
# set()
# 1941
# 1942
# set()
# 1941
# 1942
# set()
# 1941
# 1942
# set()
# 1941
# 1938
# {'2019-12-17 12:01:00', '2019-12-12 11:00:00', '2019-12-16 11:02:00', '2019-12-18 11:01:00', '2019-12-18 11:31:00', '2019-12-16 09:32:00', '2019-12-16 09:33:00', '2019-12-17 11:29:00', '2019-12-13 11:04:00', '2019-12-16 12:00:00'}
# 1937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6a46550de71a> in <module>
#       8     data, meta_data = ts.get_intraday(interval='1min', symbol='MSFT', outputsize='full')
#       9     print(len(data))
# ---> 10     time.sleep(20)
#      11     data2, meta_data2 = ts.get_intraday(interval='1min', symbol='TSLA',  outputsize='full')
#      12     print(len(data2))
#
# KeyboardInterrupt:

# %%
# !python Oracle.py
