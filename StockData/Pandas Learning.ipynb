# %% [markdown]
# Pandas

# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 5

# %%
tickers = ['MSFT2019-10-25.csv', 'MU2019-10-25.csv']
test = dict()
for i in tickers:
    original_data = pd.read_csv(i)
    data = original_data.copy()
    test[i] = data

# test['MSFT2019-10-25.csv']['4. close']
test['MU2019-10-25.csv']
# Out:
#                      date  1. open  2. high   3. low  4. close  5. volume
# 0     2019-10-22 09:31:00  45.3000   45.500  45.3000   45.3900   267340.0
# 1     2019-10-22 09:32:00  45.3612   45.424  45.3139   45.3242    81076.0
# ...                   ...      ...      ...      ...       ...        ...
# 1941  2019-10-28 15:59:00  48.7200   48.750  48.6900   48.7400   323339.0
# 1942  2019-10-28 16:00:00  48.7400   48.750  48.6900   48.7000   343700.0
#
# [1943 rows x 6 columns]

# %%
original_data = pd.read_csv('MSFT2019-10-25.csv')

data = original_data.copy()

close_time = data[['date', '4. close']]

time = data['date']

close = data['4. close'] 

# time = pd.to_datetime(data['date'])
time_index = pd.DatetimeIndex(time.values)
time_data = data.set_index(time_index)
time_data.drop('date',axis=1,inplace=True)

# Placeholder function is mean() but can do others.

d60min = time_data.resample('60min').mean()
d30min = time_data.resample('30min').mean()
d15min = time_data.resample('15min').mean()
d10min = time_data.resample('10min').mean()
d5min = time_data.resample('5min').mean()

d5min
# Out:
#                       1. open   2. high    3. low    4. close  5. volume
# 2019-10-22 09:30:00  139.2000  139.3400  139.1625  139.283775  228675.75
# 2019-10-22 09:35:00  139.4253  139.4873  139.4122  139.474200  133354.60
# ...                       ...       ...       ...         ...        ...
# 2019-10-28 15:55:00  144.0886  144.1230  144.0680  144.095860  137497.80
# 2019-10-28 16:00:00  144.1200  144.2600  144.0900  144.200000  532315.00
#
# [1807 rows x 5 columns]

# %% [markdown]
# Threading

# %%
import logging
import threading
import time

def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)

if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO,
                        datefmt="%H:%M:%S")

    logging.info("Main    : before creating thread")
    x = threading.Thread(target=thread_function, args=(1,))
    logging.info("Main    : before running thread")
    x.start()
    logging.info("Main    : wait for the thread to finish")
    # x.join()
    logging.info("Main    : all done")
# Out:
# 16:01:01: Main    : before creating thread
# 16:01:01: Main    : before running thread
# 16:01:01: Thread 1: starting
# 16:01:01: Main    : wait for the thread to finish
# 16:01:01: Main    : all done

# %%
import logging
import threading
import time

def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)

if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO,
                        datefmt="%H:%M:%S")

    threads = list()
    for index in range(3):
        logging.info("Main    : create and start thread %d.", index)
        x = threading.Thread(target=thread_function, args=(index,))
        threads.append(x)
        x.start()

    for index, thread in enumerate(threads):
        logging.info("Main    : before joining thread %d.", index)
        thread.join()
        logging.info("Main    : thread %d done", index)
# Out:
# 16:01:01: Main    : create and start thread 0.
# 16:01:01: Thread 0: starting
# 16:01:01: Main    : create and start thread 1.
# 16:01:01: Thread 1: starting
# 16:01:01: Main    : create and start thread 2.
# 16:01:01: Thread 2: starting
# 16:01:01: Main    : before joining thread 0.
# 16:01:03: Thread 1: finishing
# 16:01:03: Thread 0: finishing
# 16:01:03: Main    : thread 0 done
# 16:01:03: Main    : before joining thread 1.
# 16:01:03: Thread 1: finishing
# 16:01:03: Main    : thread 1 done
# 16:01:03: Main    : before joining thread 2.
# 16:01:03: Thread 2: finishing
# 16:01:03: Main    : thread 2 done
