# %%
import pandas as pd
import numpy as np

# pd.options.display.max_rows = 4000

# %%
data = pd.read_csv('MSFT2019-10-25.csv')

close = data[['date', '4. close']]

time = data['date']

print(time)
# Out:
# 0       2019-10-22 09:31:00
# 1       2019-10-22 09:32:00
# 2       2019-10-22 09:33:00
# 3       2019-10-22 09:34:00
# 4       2019-10-22 09:35:00
# 5       2019-10-22 09:36:00
# 6       2019-10-22 09:37:00
# 7       2019-10-22 09:38:00
# 8       2019-10-22 09:39:00
# 9       2019-10-22 09:40:00
# 10      2019-10-22 09:41:00
# 11      2019-10-22 09:42:00
# 12      2019-10-22 09:43:00
# 13      2019-10-22 09:44:00
# 14      2019-10-22 09:45:00
# 15      2019-10-22 09:46:00
# 16      2019-10-22 09:47:00
# 17      2019-10-22 09:48:00
# 18      2019-10-22 09:49:00
# 19      2019-10-22 09:50:00
# 20      2019-10-22 09:51:00
# 21      2019-10-22 09:52:00
# 22      2019-10-22 09:53:00
# 23      2019-10-22 09:54:00
# 24      2019-10-22 09:55:00
# 25      2019-10-22 09:56:00
# 26      2019-10-22 09:57:00
# 27      2019-10-22 09:58:00
# 28      2019-10-22 09:59:00
# 29      2019-10-22 10:00:00
# 30      2019-10-22 10:01:00
# 31      2019-10-22 10:02:00
# 32      2019-10-22 10:03:00
# ...
